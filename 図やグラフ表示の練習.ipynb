# %%
2+2
# Out:
# 4

# %%
width = 20
height = 5 * 9
width * height
# Out:
# 900

# %%
4 * 3.75 - 1
# Out:
# 14.0

# %%
'"Isn\'t," they said.'
# Out:
# '"Isn\'t," they said.'

# %%
print('"Isn\'t," they said.')
# Out:
# "Isn't," they said.

# %%
s = 'First line.\nSecond line.'  # \n means newline
s  # without print(), \n is included in the output
# Out:
# 'First line.\nSecond line.'

# %%
print(s)  # with print(), \n produces a new line
# Out:
# First line.
# Second line.

# %%
print('C:\some\name')  # here \n means newline!
# Out:
# C:\some
# ame

# %%
print("""\
Usage: thingy [OPTIONS]
     -h                        Display this usage message
     -H hostname               Hostname to connect to
""")
# Out:
# Usage: thingy [OPTIONS]
#      -h                        Display this usage message
#      -H hostname               Hostname to connect to

# %%
>>> # 3 times 'un', followed by 'ium'
>>> 3 * 'un' + 'ium'
# Out:
# 'unununium'

# %%
text = ('Put several strings within parentheses '
...         'to have them joined together.')
text
# Out:
# 'Put several strings within parentheses to have them joined together.'

# %%
word = 'Python'
word[0:6]  # character in position 0
# Out:
# 'Python'

# %%
word[4:42]
# Out:
# 'on'

# %%
'J' + word[1:]
# Out:
# 'Jython'

# %%
word[:2] + 'py'
# Out:
# 'Pypy'

# %%
word
# Out:
# 'Python'

# %%
s = 'supercalifragilisticexpialidocious'
len(s)
# Out:
# 34

# %%
orange = {'price': 1, 'stock': 30}
# add 20 oranges
orange['stock'] += 20
for key in orange:

    print(key+ ':'+str(orange[key]))
# Out:
# price:1
# stock:50

# %%
def tashizan(num1, num2):
    result = num1 + num2
    return result

test = tashizan(1, 2)
print(test)
# Out:
# 3

# %%
squares = [1, 4, 9, 16, 25]
squares
# Out:
# [1, 4, 9, 16, 25]

# %%
squares + [36, 49, 64, 81, 100]
# Out:
# [1, 4, 9, 16, 25, 36, 49, 64, 81, 100]

# %%
a = ['a', 'b', 'c']
n = [1, 2, 3]
x = [a, n]
print(x)

print(x[0])

x[0][2]
# Out:
# [['a', 'b', 'c'], [1, 2, 3]]
# ['a', 'b', 'c']
# 'c'

# %%
import pandas as pd

df = pd.read_csv('aaa.csv', encoding="shift-jis")

df
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-24-2c2434396144> in <module>
#       1 import pandas as pd
#       2
# ----> 3 df = pd.read_csv('aaa.csv', encoding="shift-jis")
#       4
#       5 df
#
# ...

# %%
import csv

df = pd.read_csv("aaa.csv", encoding="shift-jis")

df['男性'].sum()

# %%
import csv
df = pd.read_csv("aaa.csv", encoding="shift-jis")

df['男性'].mean()

# %%
type('日付')

# %%
type('男性')

# %%
list_num = [1,2,3,4]
list_num

# %%
list_num[0] = 9
list_num
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-b4b4301c08d8> in <module>
# ----> 1 list_num[0] = 9
#       2 list_num
#
# NameError: name 'list_num' is not defined

# %%
tupple_num = [4,5,6,7]
tupple_num
# Out:
# [4, 5, 6, 7]

# %%
tupple_num = [4,5,6,7]
tupple_num[0] = 9
tupple_num
# Out:
# [9, 5, 6, 7]

# %%
kyushu_pop_dict = {"Fukuoka":504, "Oita":120, "Kumamoto":102}
kyushu_pop_dict
# Out:
# {'Fukuoka': 504, 'Oita': 120, 'Kumamoto': 102}

# %%
kyushu_pop_dict["Fukuoka"]
# Out:
# 504

# %%
kyushu_pop_dict.update({"Fukuoka":170, "Oita":114, "Kumamoto":85, "Nagasaki":89, "Saga":54})
kyushu_pop_dict
# Out:
# {'Fukuoka': 170, 'Oita': 114, 'Kumamoto': 85, 'Nagasaki': 89, 'Saga': 54}

# %%
#　pi：円周率　r：半径　s:円の面積
pi = 3.14
r = 2.0
s = pi * r ** 2 
s
# Out:
# 12.56

# %%
import pandas as pd
sensor_df = pd.read_csv('000_Et_H_CO_n.csv') # データセットの読み込み
sensor_df.columns = ['Time', 'Temperature', 'Relative Humidity', 'Sensor1', 'Sensor2', 'Sensor3', 'Sensor4', 'Sensor5', 'Sensor6', 'Sensor7', 'Sensor8'] # 列名を付与
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-32-b95724f04568> in <module>
#       1 import pandas as pd
# ----> 2 sensor_df = pd.read_csv('000_Et_H_CO_n.csv') # データセットの読み込み
#       3 sensor_df.columns = ['Time', 'Temperature', 'Relative Humidity', 'Sensor1', 'Sensor2', 'Sensor3', 'Sensor4', 'Sensor5', 'Sensor6', 'Sensor7', 'Sensor8'] # 列名を付与
#
# ...

# %%
sensor_df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-33-9088c03ffa62> in <module>
# ----> 1 sensor_df.head()
#
# NameError: name 'sensor_df' is not defined

# %%
import matplotlib.pyplot as plt
plt.plot(sensor_df['Time'], sensor_df['Sensor1']) # 折れ線グラフをプロット

plt.title('Transition of Sensor1 value')          # 図のタイトル
plt.xlabel('Time (s)')                            # x軸のラベル
plt.ylabel('Value')                               # y軸のラベル

plt.show()                                        # 図の表示
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-34-36651e618620> in <module>
#       1 import matplotlib.pyplot as plt
# ----> 2 plt.plot(sensor_df['Time'], sensor_df['Sensor1']) # 折れ線グラフをプロット
#       3
#       4 plt.title('Transition of Sensor1 value')          # 図のタイトル
#       5 plt.xlabel('Time (s)')                            # x軸のラベル
#
# NameError: name 'sensor_df' is not defined

# %%
import matplotlib.pyplot as plt
# 複数の折れ線グラフをプロット：線の色（color）・点のマーカー（marker）・線の種類（linetype）・凡例表示のためのラベル（label）でグラフを区別
plt.plot(sensor_df['Time'], sensor_df['Sensor1'], color = 'red', marker = 'o', linestyle = '-', label = 'Sensor1')
plt.plot(sensor_df['Time'], sensor_df['Sensor2'], color = 'green', marker = 'x', linestyle = '--', label = 'Sensor2')
plt.plot(sensor_df['Time'], sensor_df['Sensor3'], color = 'blue', marker = 's', linestyle = ':', label = 'Sensor3')
plt.plot(sensor_df['Time'], sensor_df['Sensor4'], color = 'orange', marker = 'v', linestyle = '-.', label = 'Sensor4')

plt.title('Transition of Sensor value') # 図のタイトル
plt.xlabel('Time (s)')                  # x軸のラベル
plt.ylabel('Value')                     # y軸のラベル
plt.legend(loc = 'upper right')         # 凡例を右上（upper right）に表示
plt.xlim([50, 51])                      # x軸方向の表示範囲を指定
plt.ylim([250, 800])                    # y軸方向の表示範囲を指定

plt.show()                              # 図の表示
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-35-c8ebbba64747> in <module>
#       1 import matplotlib.pyplot as plt
#       2 # 複数の折れ線グラフをプロット：線の色（color）・点のマーカー（marker）・線の種類（linetype）・凡例表示のためのラベル（label）でグラフを区別
# ----> 3 plt.plot(sensor_df['Time'], sensor_df['Sensor1'], color = 'red', marker = 'o', linestyle = '-', label = 'Sensor1')
#       4 plt.plot(sensor_df['Time'], sensor_df['Sensor2'], color = 'green', marker = 'x', linestyle = '--', label = 'Sensor2')
#       5 plt.plot(sensor_df['Time'], sensor_df['Sensor3'], color = 'blue', marker = 's', linestyle = ':', label = 'Sensor3')
#
# NameError: name 'sensor_df' is not defined

# %%
import matplotlib.pyplot as plt
fig, axe = plt.subplots(2, 2) # 図を2行2列に分割

# 各領域で折れ線グラフをプロット
axe[0, 0].plot(sensor_df['Time'], sensor_df['Sensor1'], color = 'red', marker = 'o', linestyle = '-', label = 'Sensor1')
axe[0, 1].plot(sensor_df['Time'], sensor_df['Sensor2'], color = 'green', marker = 'x', linestyle = '--', label = 'Sensor2')
axe[1, 0].plot(sensor_df['Time'], sensor_df['Sensor3'], color = 'blue', marker = 's', linestyle = ':', label = 'Sensor3')
axe[1, 1].plot(sensor_df['Time'], sensor_df['Sensor4'], color = 'orange', marker = 'v', linestyle = '-.', label = 'Sensor4')

# 各グラフのタイトル・x軸のラベル・y軸のラベルを設定
axe[0, 0].set_title('Transition of Sensor1 value')
axe[0, 0].set_xlabel('Time (s)')
axe[0, 0].set_ylabel('Value')

axe[0, 1].set_title('Transition of Sensor2 value')
axe[0, 1].set_xlabel('Time (s)')
axe[0, 1].set_ylabel('Value')

axe[1, 0].set_title('Transition of Sensor3 value')
axe[1, 0].set_xlabel('Time (s)')
axe[1, 0].set_ylabel('Value')

axe[1, 1].set_title('Transition of Sensor4 value')
axe[1, 1].set_xlabel('Time (s)')
axe[1, 1].set_ylabel('Value')

plt.tight_layout() # ラベル・タイトルが被らないように配置
plt.show()         # 図の表示
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-36-ecf6f6ca908f> in <module>
#       3
#       4 # 各領域で折れ線グラフをプロット
# ----> 5 axe[0, 0].plot(sensor_df['Time'], sensor_df['Sensor1'], color = 'red', marker = 'o', linestyle = '-', label = 'Sensor1')
#       6 axe[0, 1].plot(sensor_df['Time'], sensor_df['Sensor2'], color = 'green', marker = 'x', linestyle = '--', label = 'Sensor2')
#       7 axe[1, 0].plot(sensor_df['Time'], sensor_df['Sensor3'], color = 'blue', marker = 's', linestyle = ':', label = 'Sensor3')
#
# NameError: name 'sensor_df' is not defined

# %%
#matplotlibのfont.familyのパラメータを確認します。
import matplotlib
print(matplotlib.rcParams['font.family'])

# %%
import matplotlib.pyplot as plt
import numpy as np

# フォントファミリーの確認
print( plt.rcParams['font.family'] )
# Out:
# ['sans-serif']

# %%
# フォントファミリー内のフォントの確認
print( plt.rcParams['font.sans-serif'] )
# Out:
# ['DejaVu Sans', 'Bitstream Vera Sans', 'Computer Modern Sans Serif', 'Lucida Grande', 'Verdana', 'Geneva', 'Lucid', 'Arial', 'Helvetica', 'Avant Garde', 'sans-serif']

# %%
import matplotlib
 
fonts = set([f.name for f in matplotlib.font_manager.fontManager.ttflist])
print(fonts)
# Out:
# {'Baskerville Old Face', 'Freestyle Script', 'Showcard Gothic', 'Courier New', 'OCR A Extended', 'Bookman Old Style', 'UD Digi Kyokasho N-B', 'Niagara Engraved', 'Lucida Fax', 'Lucida Handwriting', 'Imprint MT Shadow', 'Goudy Old Style', 'Lucida Sans Unicode', 'Eras Demi ITC', 'cmb10', 'Maiandra GD', 'Comic Sans MS', 'SimSun-ExtB', 'cmss10', 'Meiryo', 'Lucida Sans Typewriter', 'Garamond', 'Palace Script MT', 'Candara', 'Felix Titling', 'Californian FB', 'Vladimir Script', 'Poor Richard', 'STIXSizeFourSym', 'MS Reference Specialty', 'Vivaldi', 'STIXGeneral', 'Segoe UI Historic', 'Gill Sans Ultra Bold', 'Wide Latin', 'Verdana', 'Harrington', 'DejaVu Sans Display', 'Bahnschrift', 'HGGyoshotai', 'Times New Roman', 'Ravie', 'HGMinchoB', 'Niagara Solid', 'MT Extra', 'Gill Sans MT Condensed', 'HoloLens MDL2 Assets', 'Georgia', 'DejaVu Serif Display', 'Modern No. 20', 'Informal Roman', 'Microsoft Yi Baiti', 'Onyx', 'Lucida Console', 'Copperplate Gothic Bold', 'HGGothicM', 'HGGothicE', 'Rage 
# ...

# %%
# フォントを全て読み込み
fonts = set([f.name for f in matplotlib.font_manager.fontManager.ttflist])
 
# 描画領域のサイズ調整
plt.figure(figsize=(10,len(fonts)/4))
 
# フォントの表示
for i, font in enumerate(fonts):
    plt.text(0, i, f"日本語：{font}", fontname=font)
    
# 見やすいように軸を消す
plt.ylim(0, len(fonts))
plt.axis("off")
    
plt.show()
# Out:
# C:\Users\2377\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 26085 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\2377\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 26412 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\2377\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 35486 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\2377\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 65306 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\2377\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 108 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...

# %%
import matplotlib.pyplot as plt
 
plt.plot()
 
plt.title("グラフタイトル", fontname = 'MS Mincho')
plt.xlabel("x軸ラベル名", fontname ='MS Gothic')
plt.ylabel("y軸ラベル名", fontname ='MS Gothic')
 
plt.text(0.5, 0.5,"テキスト例",  fontname="Meiryo")
 
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime

from matplotlib.font_manager import FontProperties
fp = FontProperties(fname=r'C:\WINDOWS\Fonts\meiryob.ttc', size=16)

import csv

#グラフの基本フォントサイズの設定
plt.rcParams['font.size'] = 10 

# figureを生成する
fig = plt.figure()
 
# axをfigureに設定する
ax = fig.add_subplot(1, 1, 1)

#ファイル読み込み(男女の日付毎の人数)
df = pd.read_csv('./data/aaa.csv', encoding="shift-jis")

df['年月日'] = pd.to_datetime(df['日付'], format='%Y%m%d')
df['年月日']

day = df['年月日']
#day = pd.to_datetime(df['日付'])
Men = df['男性']
Women = df['女性']

#グラフ表示内容の設定
ax.plot(day, Men, color = "blue", linestyle = "--");
ax.plot(day, Women, color = "red",  linestyle = ":");
#ax.set_title("people_count", fontsize=15, fontweight="bold", style="italic")
ax.set_title("タイトル「人流計測」", fontsize=15, fontweight="bold", fontname = 'Meiryo') #Meiryoで記述

ax.set_xlabel("「年月日」", fontname = 'MS gothic') #ゴシック体で記述
ax.set_ylabel("「人数」", fontname = 'MS Mincho') #明朝体で記述
ax.grid()

# %%
import datetime
print(datetime.timedelta(days=0.5, hours=-6, minutes=120))

print(datetime.date.today())

print(datetime.datetime.today())
# Out:
# 8:00:00
# 2021-09-17
# 2021-09-17 15:17:45.561621

# %%
datetime_format = datetime.datetime(2021, 6, 22, 12, 15, 28)
print(datetime_format.strftime("%Y/%m/%d"))
print(datetime_format.strftime("%Y/%m/%d %H:%M:%S"))
# Out:
# 2021/06/22
# 2021/06/22 12:15:28

# %%
from datetime import datetime as dt

tstr = '2012-12-29 13:49:37'
tdatetime = dt.strptime(tstr, '%Y-%m-%d %H:%M:%S')

tdatetime
# Out:
# datetime.datetime(2012, 12, 29, 13, 49, 37)

# %%
from datetime import datetime as dt

#ファイル読み込み(男女の日付毎の人数)
df = pd.read_csv('./data/aaa.csv', encoding="shift-jis")
day = pd.to_datetime(df['日付'])

day
# Out:
# 0    1970-01-01 00:00:00.020200501
# 1    1970-01-01 00:00:00.020200502
# 2    1970-01-01 00:00:00.020200503
# 3    1970-01-01 00:00:00.020200504
# 4    1970-01-01 00:00:00.020200505
# 5    1970-01-01 00:00:00.020200506
# 6    1970-01-01 00:00:00.020200507
# 7    1970-01-01 00:00:00.020200508
# 8    1970-01-01 00:00:00.020200509
# 9    1970-01-01 00:00:00.020200510
# 10   1970-01-01 00:00:00.020200511
# 11   1970-01-01 00:00:00.020200512
# 12   1970-01-01 00:00:00.020200513
# 13   1970-01-01 00:00:00.020200514
# 14   1970-01-01 00:00:00.020200515
# 15   1970-01-01 00:00:00.020200516
# 16   1970-01-01 00:00:00.020200517
# 17   1970-01-01 00:00:00.020200518
# 18   1970-01-01 00:00:00.020200519
# 19   1970-01-01 00:00:00.020200520
# 20   1970-01-01 00:00:00.020200521
# 21   1970-01-01 00:00:00.020200522
# 22   1970-01-01 00:00:00.020200523
# 23   1970-01-01 00:00:00.020200524
# 24   1970-01-01 00:00:00.020200525
# 25   1970-01-01 00:00:00.020200526
# 26   1970-01-01 00:00:00.020200527
# ...

# %%
import datetime

str = '20210501'
dte = datetime.datetime.strptime(str, '%Y%m%d')
print(dte)

print(type(str))
# Out:
# 2021-05-01 00:00:00
# <class 'str'>

# %%
from datetime import datetime as dt

#ファイル読み込み(男女の日付毎の人数)
df = pd.read_csv('./data/aaa.csv', encoding="shift-jis")
df['日付']

pd.to_datetime(df['日付'])
#pd.to_datetime(df['日付'].astype(str))
# Out:
# 0    1970-01-01 00:00:00.020200501
# 1    1970-01-01 00:00:00.020200502
# 2    1970-01-01 00:00:00.020200503
# 3    1970-01-01 00:00:00.020200504
# 4    1970-01-01 00:00:00.020200505
# 5    1970-01-01 00:00:00.020200506
# 6    1970-01-01 00:00:00.020200507
# 7    1970-01-01 00:00:00.020200508
# 8    1970-01-01 00:00:00.020200509
# 9    1970-01-01 00:00:00.020200510
# 10   1970-01-01 00:00:00.020200511
# 11   1970-01-01 00:00:00.020200512
# 12   1970-01-01 00:00:00.020200513
# 13   1970-01-01 00:00:00.020200514
# 14   1970-01-01 00:00:00.020200515
# 15   1970-01-01 00:00:00.020200516
# 16   1970-01-01 00:00:00.020200517
# 17   1970-01-01 00:00:00.020200518
# 18   1970-01-01 00:00:00.020200519
# 19   1970-01-01 00:00:00.020200520
# 20   1970-01-01 00:00:00.020200521
# 21   1970-01-01 00:00:00.020200522
# 22   1970-01-01 00:00:00.020200523
# 23   1970-01-01 00:00:00.020200524
# 24   1970-01-01 00:00:00.020200525
# 25   1970-01-01 00:00:00.020200526
# 26   1970-01-01 00:00:00.020200527
# ...

# %%
import pandas as pd
import locale
import datetime

#ファイル読み込み(男女の日付毎の人数)
df = pd.read_csv('./data/aaa.csv', encoding="shift-jis")

df['年月日'] = pd.to_datetime(df['日付'], format='%Y%m%d')
df['年月日']
# Out:
# 0    2020-05-01
# 1    2020-05-02
# 2    2020-05-03
# 3    2020-05-04
# 4    2020-05-05
# 5    2020-05-06
# 6    2020-05-07
# 7    2020-05-08
# 8    2020-05-09
# 9    2020-05-10
# 10   2020-05-11
# 11   2020-05-12
# 12   2020-05-13
# 13   2020-05-14
# 14   2020-05-15
# 15   2020-05-16
# 16   2020-05-17
# 17   2020-05-18
# 18   2020-05-19
# 19   2020-05-20
# 20   2020-05-21
# 21   2020-05-22
# 22   2020-05-23
# 23   2020-05-24
# 24   2020-05-25
# 25   2020-05-26
# 26   2020-05-27
# 27   2020-05-28
# 28   2020-05-29
# 29   2020-05-30
# Name: 年月日, dtype: datetime64[ns]

# %%
import pandas as pd
import locale

locale.setlocale(locale.LC_TIME, 'ja_JP.UTF-8')

s = '2018-01-01'
s_dow = datetime.datetime.strptime(s, '%Y-%m-%d')

print(s_dow)
# Out:
# 2018-01-01 00:00:00

# %%
import datetime

dt = datetime.datetime.strptime("2020/07/22 10:4:38", "%Y/%m/%d %H:%M:%S")
print(dt)
# Out:
# 2020-07-22 10:04:38

# %%
import datetime

str1 = "2020/07/22 13:37:4:33217"
str2 = "07/22/2020 PM 1:37:4:33217"
str3 = "July 22,2020 13:37:4:33217+09:00"

dt1 = datetime.datetime.strptime(str1, "%Y/%m/%d %H:%M:%S:%f")

print(dt1)
# Out:
# 2020-07-22 13:37:04.332170

# %%
#菱電センサの温度情報の読み込み、グラフ化
import pandas as pd
import numpy as np

from tqdm import tqdm
import time

# %matplotlib inline
import matplotlib
matplotlib.rcParams['font.family'] = 'Arial Unicode MS'

#reader = pd.read_csv('C:/Users/2377/Desktop/作業スペース/RAWDATA 2107_.csv',
#                  encoding='UTF-8', index_col=0, header=0)

reader = pd.read_csv('C:/Users/2377/Desktop/作業スペース/RAWDATA 210701_0731_m(温湿度該当データ抜粋)_.csv',
                  encoding='UTF-8', index_col=0, header=0)

#reader = pd.read_excel('C:/Users/2377/Desktop/作業スペース/RAWDATA 210701_0731_m.xlsx', index_col=0)
#reader = pd.read_excel('C:/Users/2377/Desktop/作業スペース/RAWDATA 210701_0731_m.xlsx', index_col=0, skiprows=1)
#reader = pd.read_excel('C:/Users/2377/Desktop/作業スペース/RAWDATA 210701_0731_m.xlsx', index_col=[0,1], header=[0, 2])

reader
# Out:
#                時間  T-S01H-H X4-Y7 H  T-S01M-T X4-Y7 M  T-S01L-T X4-Y7 L 温度  \
# 年日
# 20210701.0   0:00              20.3               NaN                 15.2
# 20210701.0   0:01              20.3               NaN                 15.2
# 20210701.0   0:02              20.3               NaN                 15.2
# 20210701.0   0:03              20.3               NaN                 15.2
# 20210701.0   0:04              20.3               NaN                 15.2
# ...           ...               ...               ...                  ...
# NaN         23:55              25.2              22.1                 16.6
# NaN         23:56              25.2              22.1                 16.6
# NaN         23:57              25.2              22.1                 16.6
# NaN         23:58              25.2              22.1                 16.6
# NaN         23:59              25.2              22.1                 16.6
#
# ...

# %%
#for r in reader:
#    print(type(r), r.shape)

# %%
# 上のループで全ての要素は読み取り済みになっているので、再度 reader を初期化
df = pd.read_csv('C:/Users/2377/Desktop/作業スペース/RAWDATA 210701_0731_m(温湿度該当データ抜粋)_.csv',
                  index_col=[0,1], header=0)

# 先頭から 5行を読み込み
df.head(10)
# Out:
#                  T-S01H-H X4-Y7 H  T-S01M-T X4-Y7 M  T-S01L-T X4-Y7 L 温度  \
# 年日         時間
# 20210701.0 0:00              20.3               NaN                 15.2
#            0:01              20.3               NaN                 15.2
#            0:02              20.3               NaN                 15.2
#            0:03              20.3               NaN                 15.2
#            0:04              20.3               NaN                 15.2
#            0:05              20.3               NaN                 15.2
#            0:06              20.9              19.0                 15.3
#            0:07              21.0               NaN                 15.3
#            0:08              21.0               NaN                 15.3
#            0:09              21.0               NaN                 15.3
#
#                  T-S02H-C X6-Y6 H 温度  T-S02M-T X6-Y6 M 温度  \
# 年日         時間
# 20210701.0 0:00                 19.2                 18.0
# ...

# %%
#df2 = df.fillna(0)
#df2.head(10)

# %%
plt.rcParams['figure.figsize'] = [20,5]

df.plot()

plt.title("温湿度グラフ",fontname="Meiryo")
# Out:
# Text(0.5, 1.0, '温湿度グラフ')
# findfont: Font family ['Arial Unicode MS'] not found. Falling back to DejaVu Sans.
# C:\Users\2377\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 24180 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\2377\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 26085 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\2377\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 26178 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\2377\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 38291 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\2377\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 28201 missing from current font.
# ...

# %%
df.mean()
# Out:
# T-S01H-H X4-Y7 H       23.194336
# T-S01M-T X4-Y7 M       20.801046
# T-S01L-T X4-Y7 L 温度    15.996520
# T-S02H-C X6-Y6 H 温度    20.955815
# T-S02M-T X6-Y6 M 温度    18.860116
#                          ...
# センサー5 湿度               67.809026
# センサー1 湿度               64.865485
# センサー6 湿度               96.478783
# センサー10 湿度              78.458943
# センサー14 湿度              65.357865
# Length: 82, dtype: float64

# %%
#df.isnull()

# %%
#from sklearn.linear_model import LinearRegression

#model_lr = LinearRegression()
#model_lr.fit('T-S01H-H X4-Y7 H 温度', 'T-S01M-T X4-Y7 M 温度')
#model_lr.fit('T-S01H-H X4-Y7 H 温度', '単位')

# %%
df.iloc[:,0:1].plot(legend=False)
# Out:
# <AxesSubplot:xlabel='年日,時間'>
# C:\Users\2377\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 24180 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\2377\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 26085 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\2377\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 26178 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\2377\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 38291 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\2377\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 24180 missing from current font.
#   font.set_text(s, 0, flags=flags)
# ...

# %%
df.iloc[:,2:3].plot(legend=False)
# Out:
# <AxesSubplot:xlabel='年日,時間'>
# C:\Users\2377\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 24180 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\2377\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 26085 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\2377\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 26178 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\2377\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 38291 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\2377\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 24180 missing from current font.
#   font.set_text(s, 0, flags=flags)
# ...

# %%
df.iloc[:,3:4].plot(legend=False)
# Out:
# <AxesSubplot:xlabel='年日,時間'>
# C:\Users\2377\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 24180 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\2377\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 26085 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\2377\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 26178 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\2377\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 38291 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\2377\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 24180 missing from current font.
#   font.set_text(s, 0, flags=flags)
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
pd.set_option('display.max_columns',3)  #指定した列数のみ表示

# %%
df
# Out:
#                   T-S01H-H X4-Y7 H  ...  センサー14 湿度
# 年日         時間                       ...
# 20210701.0 0:00               20.3  ...      67.65
#            0:01               20.3  ...      67.67
#            0:02               20.3  ...      67.69
#            0:03               20.3  ...      67.67
#            0:04               20.3  ...      67.72
# ...                            ...  ...        ...
# NaN        23:55              25.2  ...      49.91
#            23:56              25.2  ...      49.94
#            23:57              25.2  ...      50.00
#            23:58              25.2  ...      49.94
#            23:59              25.2  ...      49.94
#
# [44640 rows x 82 columns]

# %%
pd.reset_option('display.max_columns') #表示をもとに戻す

# %%
df
# Out:
#                   T-S01H-H X4-Y7 H  T-S01M-T X4-Y7 M  T-S01L-T X4-Y7 L 温度  \
# 年日         時間
# 20210701.0 0:00               20.3               NaN                 15.2
#            0:01               20.3               NaN                 15.2
#            0:02               20.3               NaN                 15.2
#            0:03               20.3               NaN                 15.2
#            0:04               20.3               NaN                 15.2
# ...                            ...               ...                  ...
# NaN        23:55              25.2              22.1                 16.6
#            23:56              25.2              22.1                 16.6
#            23:57              25.2              22.1                 16.6
#            23:58              25.2              22.1                 16.6
#            23:59              25.2              22.1                 16.6
#
#                   T-S02H-C X6-Y6 H 温度  T-S02M-T X6-Y6 M 温度  \
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of                   T-S01H-H X4-Y7 H  T-S01M-T X4-Y7 M  T-S01L-T X4-Y7 L 温度  \
# 年日         時間
# 20210701.0 0:00               20.3               NaN                 15.2
#            0:01               20.3               NaN                 15.2
#            0:02               20.3               NaN                 15.2
#            0:03               20.3               NaN                 15.2
#            0:04               20.3               NaN                 15.2
# ...                            ...               ...                  ...
# NaN        23:55              25.2              22.1                 16.6
#            23:56              25.2              22.1                 16.6
#            23:57              25.2              22.1                 16.6
#            23:58              25.2              22.1                 16.6
#            23:59              25.2              22.1                 16.6
#
# ...

# %%
df.describe() #要約統計量の取得　(カウント数、平均値、標準偏差、最小値～最大値(四分位数)など)
# Out:
#        T-S01H-H X4-Y7 H  T-S01M-T X4-Y7 M  T-S01L-T X4-Y7 L 温度  \
# count      42746.000000      40996.000000         41065.000000
# mean          23.194336         20.801046            15.996520
# std            1.430369          4.051585             1.739419
# min           20.200000         18.600000            14.600000
# 25%           22.000000         19.800000            15.600000
# 50%           23.100000         20.500000            15.900000
# 75%           24.200000         21.300000            16.300000
# max           27.400000         99.900000            99.900000
#
#        T-S02H-C X6-Y6 H 温度  T-S02M-T X6-Y6 M 温度  T-S02L-T X6-Y6 L 温度  \
# count         38316.000000         42395.000000         42723.000000
# mean             20.955815            18.860116            13.070838
# std               3.299113             2.027981             0.867257
# min              18.700000            16.500000            10.800000
# ...

# %%
df.describe().round(0)  #describeメソッドに加え、小数点以下を丸める
# Out:
#        T-S01H-H X4-Y7 H  T-S01M-T X4-Y7 M  T-S01L-T X4-Y7 L 温度  \
# count           42746.0           40996.0              41065.0
# mean               23.0              21.0                 16.0
# std                 1.0               4.0                  2.0
# min                20.0              19.0                 15.0
# 25%                22.0              20.0                 16.0
# 50%                23.0              20.0                 16.0
# 75%                24.0              21.0                 16.0
# max                27.0             100.0                100.0
#
#        T-S02H-C X6-Y6 H 温度  T-S02M-T X6-Y6 M 温度  T-S02L-T X6-Y6 L 温度  \
# count              38316.0              42395.0              42723.0
# mean                  21.0                 19.0                 13.0
# std                    3.0                  2.0                  1.0
# min                   19.0                 16.0                 11.0
# ...

# %%
#pip install ggplot

# %%
#pip install plotnine

# %%
#菱電センサの温度情報の読み込み、グラフ化
import pandas as pd
import numpy as np
import matplotlib

from tqdm import tqdm
import time

#%matplotlib inline
import matplotlib as plt
matplotlib.rcParams['font.family'] = 'Arial Unicode MS'
#matplotlib.rcParams['font.family'] = 'Times New Roman'

#from plotnine import *

#reader = pd.read_csv('C:/Users/2377/Desktop/作業スペース/RAWDATA 2107_.csv',
#                  encoding='UTF-8', index_col=0, header=0)

df = pd.read_csv('C:/Users/2377/Desktop/作業スペース/RAWDATA 210701_0731_m(温湿度該当データ抜粋)_.csv',
                  encoding='UTF-8', header=0)

#df = df.set_index(['年日', '時間'])

#複数のカラム名を変更
df_base = df.rename(columns={'年日': 'Day'
                            ,'時間': 'Time'
                            ,'T-S01H-H X4-Y7 H': 'S01H'
                            ,'T-S01M-T X4-Y7 M': 'S01M'
                            ,'T-S01L-T X4-Y7 L 温度': 'S01L'
                            ,'T-S02H-C X6-Y6 H 温度': 'S02H'
                            ,'T-S02M-T X6-Y6 M 温度': 'S02M'
                            ,'T-S02L-T X6-Y6 L 温度': 'S02L'
                            ,'T-S03H-H X5-Y6 H 温度': 'S03H'
                            ,'T-S03M-T X5-Y6 M 温度': 'S03M'
                            ,'T-S03L-T X5-Y6 L 温度': 'S03L'
                            ,'T-S04H-H X4-Y6 H 温度': 'S04H'
                            ,'T-S04M-T X4-Y6 M 温度': 'S04M'
                            ,'T-S04L-T X4-Y6 L 温度': 'S04L'
                            ,'T-S05H-H X6-Y5 H 温度': 'S05H'
                            ,'T-S05M-T X6-Y5 M 温度': 'S05M'
                            ,'T-S05L-T X6-Y5 L 温度': 'S05L'
                            ,'T-S06H-H X5-Y5 H 温度': 'S06H'
                            ,'T-S06M-T X5-Y5 M 温度': 'S06M'
                            ,'T-S06L-T X5-Y5 L 温度': 'S06L'
                            ,'T-S07H-H X4-Y5 H 温度': 'S07H'
                            ,'T-S07M-T X4-Y5 M 温度': 'S07M'
                            ,'T-S07L-T X4-Y5 L 温度': 'S07L'
                            ,'T-S08H-H X6-Y4 H 温度': 'S08H'
                            ,'T-S08M-T X6-Y4 M 温度': 'S08M'
                            ,'T-S08L-T X6-Y4 L 温度': 'S08L'
                            ,'T-S09H-H X5-Y4 H 温度': 'S09H'
                            ,'T-S09M-T X5-Y4 M 温度': 'S09M'
                            ,'T-S09L-T X5-Y4 L 温度': 'S09L'
                            ,'T-S10H-H X4-Y4 H 温度': 'S10H'
                            ,'T-S10M-T X4-Y4 M 温度': 'S10M'
                            ,'T-S10L-T X4-Y4 L 温度': 'S10L'
                            ,'T-S11H-C X6-Y3 H 温度': 'S11H'
                            ,'T-S11M-T X6-Y3 M 温度': 'S11M'
                            ,'T-S11L-T X6-Y3 L 温度': 'S11L'
                            ,'T-S12H-H X5-Y3 H 温度': 'S12H'
                            ,'T-S12M-T X5-Y3 M 温度': 'S12M'
                            ,'T-S12L-T X5-Y3 L 温度': 'S12L'
                            ,'T-S13H-H X4-Y3 H 温度': 'S13H'
                            ,'T-S13M-T X4-Y3 M 温度': 'S13M'
                            ,'T-S13L-T X4-Y3 L 温度': 'S13L'
                            ,'T-S14H-H 南西入口 H 温度': 'S14H'
                            ,'T-S14M-T 南西入口 M 温度': 'S14M'
                            ,'T-S14L-T 南西入口 L 温度': 'S14L'})


df_base = df_base.set_index(['Day', 'Time'])

#df_base.rename(index={'Day2':'Day'}, level=0)
#df_base.rename(index={'19800504':'20210701'}, level=0)
#df_base.rename(index={'Time2':'Time'}, level=0)

#インデックスとカラム名を変更する際の記述例
#df_new = df.rename(columns={'A': 'Col_1'}, index={'ONE': 'Row_1'})

#reader = pd.read_excel('C:/Users/2377/Desktop/作業スペース/RAWDATA 210701_0731_m.xlsx', index_col=0)
#reader = pd.read_excel('C:/Users/2377/Desktop/作業スペース/RAWDATA 210701_0731_m.xlsx', index_col=0, skiprows=1)
#reader = pd.read_excel('C:/Users/2377/Desktop/作業スペース/RAWDATA 210701_0731_m.xlsx', index_col=[0,1], header=[0, 2])

df_base
# Out:
#                   S01H  S01M  S01L  S02H  S02M  S02L  S03H  S03M  S03L  S04H  \
# Day        Time
# 20210701.0 0:00   20.3   NaN  15.2  19.2  18.0  12.4  19.8  18.1  13.0   NaN
#            0:01   20.3   NaN  15.2  19.2  18.0  12.4  19.8  18.1  13.0   NaN
#            0:02   20.3   NaN  15.2  19.2  18.0  12.4  19.8  18.1  13.0   NaN
#            0:03   20.3   NaN  15.2  19.2  18.0  12.4  19.8  18.1  13.0   NaN
#            0:04   20.3   NaN  15.2  19.2  18.0  12.4  19.8  18.1  13.0   NaN
# ...                ...   ...   ...   ...   ...   ...   ...   ...   ...   ...
# NaN        23:55  25.2  22.1  16.6  22.3  20.4  13.6  23.3  20.8  14.5  23.9
#            23:56  25.2  22.1  16.6  22.3  20.4  13.6  23.3  20.8  14.5  23.9
#            23:57  25.2  22.1  16.6  22.3  20.4  13.6  23.3  20.8  14.5  23.9
#            23:58  25.2  22.1  16.6  22.3  20.4  13.6  23.3  20.8  14.5  23.9
#            23:59  25.2  22.1  16.6  22.3  20.4  13.6  23.3  20.8  14.5  23.9
#
# ...

# %%
#欠損値の抽出確認
#print(df_base.isnull())

print(df_base['S04H'].isnull())

#列のisnull()メソッドで欠損値がTrue、それ以外がFalseとなる

#列で指定する場合は以下のような記述になる(データフレーム「df」の列「point」)
#print(df['point'].isnull())
# Out:
# Day         Time
# 20210701.0  0:00      True
#             0:01      True
#             0:02      True
#             0:03      True
#             0:04      True
#                      ...
# NaN         23:55    False
#             23:56    False
#             23:57    False
#             23:58    False
#             23:59    False
# Name: S04H, Length: 44640, dtype: bool

# %%
#データ抽出(条件設定)

#毎時0分の条件のみ抽出
print(df_base.query('Time == "0:00"'))
# Out:
#                  S01H  S01M  S01L  S02H  S02M  S02L  S03H  S03M  S03L  S04H  \
# Day        Time
# 20210701.0 0:00  20.3   NaN  15.2  19.2  18.0  12.4  19.8  18.1  13.0   NaN
# 20210702.0 0:00  21.3  19.2  15.3  19.0  17.3  12.4  20.2  18.4  12.9   NaN
# 20210703.0 0:00  20.9   NaN  15.4  19.1  16.9  12.1  19.9  18.4  13.0  20.4
# 20210704.0 0:00  21.4  19.5   NaN  19.5  17.5  12.4  20.5  18.9  13.5  20.9
# 20210705.0 0:00  21.6  19.7  15.2  19.7  17.4  12.2   NaN  19.2  13.0  21.5
# 20210706.0 0:00  21.4  19.4  15.2  19.5  17.2  12.0  20.4  18.7  13.2  21.1
# 20210707.0 0:00  20.2  18.9  15.2  18.8  16.7  12.4  19.9  17.8  14.1  20.4
# 20210708.0 0:00  20.8  18.8  15.0   NaN  16.7  12.0  20.0  18.2  11.9  20.3
# 20210709.0 0:00  21.2   NaN  15.0  19.4  17.2  12.5  20.2  18.5  12.7  20.6
# 20210710.0 0:00  21.4  19.1  15.1  19.6  17.3  11.7  20.5  18.6  13.3  20.8
# 20210711.0 0:00  21.7  19.3  15.1   NaN  17.3  12.3  20.7  18.6  13.1  20.9
# ...

# %%
#1時間毎に抽出したデータをデータフレームに格納
df_hour = df_base.query('Time == "0:00"')

df_hour
# Out:
#                  S01H  S01M  S01L  S02H  S02M  S02L  S03H  S03M  S03L  S04H  \
# Day        Time
# 20210701.0 0:00  20.3   NaN  15.2  19.2  18.0  12.4  19.8  18.1  13.0   NaN
# 20210702.0 0:00  21.3  19.2  15.3  19.0  17.3  12.4  20.2  18.4  12.9   NaN
# 20210703.0 0:00  20.9   NaN  15.4  19.1  16.9  12.1  19.9  18.4  13.0  20.4
# 20210704.0 0:00  21.4  19.5   NaN  19.5  17.5  12.4  20.5  18.9  13.5  20.9
# 20210705.0 0:00  21.6  19.7  15.2  19.7  17.4  12.2   NaN  19.2  13.0  21.5
# 20210706.0 0:00  21.4  19.4  15.2  19.5  17.2  12.0  20.4  18.7  13.2  21.1
# 20210707.0 0:00  20.2  18.9  15.2  18.8  16.7  12.4  19.9  17.8  14.1  20.4
# 20210708.0 0:00  20.8  18.8  15.0   NaN  16.7  12.0  20.0  18.2  11.9  20.3
# 20210709.0 0:00  21.2   NaN  15.0  19.4  17.2  12.5  20.2  18.5  12.7  20.6
# 20210710.0 0:00  21.4  19.1  15.1  19.6  17.3  11.7  20.5  18.6  13.3  20.8
# 20210711.0 0:00  21.7  19.3  15.1   NaN  17.3  12.3  20.7  18.6  13.1  20.9
# ...

# %%
#グラフ化 (列1～42の温度のみ抽出)
df_hour_temp = df_hour.iloc[:,0:42]
df_hour_temp.plot()


#グラフ化 (列1～82の全てのカラム抽出)
df_hour_all = df_hour.iloc[:,0:82]
df_hour_all.plot()
# Out:
# <AxesSubplot:xlabel='Day,Time'>
# C:\Users\2377\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 12475 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\2377\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 12531 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\2377\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 12469 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\2377\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 12540 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\2377\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 28201 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...

# %%
###「Pandasのプロット機能」###

# グラフ化に必要なものの準備
import matplotlib
import matplotlib.pyplot as plt

# 画像出力に必要なものの準備
#from ggplot import *

# データの扱いに必要なライブラリ
import pandas as pd
import numpy as np
import datetime as dt

# グラフを綺麗に描画するためのおまじない
plt.style.use('ggplot') 
font = {'family' : 'meiryo'}
matplotlib.rc('font', **font)

# グラフのサイズ、色の濃さ、タイトル表示
df_hour_temp.plot.bar(y=['S01H','S01M','S01L'], alpha=0.8, figsize=(12,6))
plt.title(u'センサ『S01』の高さ毎の棒グラフ', size=16)

# グラフのアウトプット
#ggsave(filename, plot = last_plot(), device = NULL, path = NULL,
#       scale = 1,  width = NA, height = NA,
#       units = c("in", "cm", "mm"), dpi = 300, limitsize = TRUE)

#ggsave("S01センサの温度グラフ.png", p5, width = 6, height = 4, dpi = 300)
# Out:
# Text(0.5, 1.0, 'センサ『S01』の高さ毎の棒グラフ')

# %%
df_hour_temp.plot.line(y=['S01H','S01M','S01L'], alpha=0.8, figsize=(12,6))

#bar：グラフ
#line：折れ線グラフ
# Out:
# <AxesSubplot:xlabel='Day,Time'>

# %%
# 比較「S01H」と「センサー7 湿度」
df_hour_all.plot.bar(y=['S01H','センサー7 湿度'], alpha=0.8, figsize=(12,6))
# Out:
# <AxesSubplot:xlabel='Day,Time'>

# %%
#S01Hの数をカウント
df_count = df_base[df_base['S01H']>=25.3].count()

df_count.tail(20)
# Out:
# T-S08H-H X6-Y4 H 湿度                                                 3666
# T-S09H-H X5-Y4 H 湿度                                                 3639
# T-S10H-H X4-Y4 H 湿度                                                 3754
# T-S11H-C X6-Y3 H 湿度                                                    0
# T-S12H-H X5-Y3 H 湿度                                                 3556
# T-S13H-H X4-Y3 H 湿度                                                 3442
# T-S14H-H 南西入口 H 湿度                                                  3718
# センサー13 湿度                                                           3997
# センサー11 湿度(センサー19と7/13 15:36に交換)                                     3997
# センサー12 湿度                                                           3997
# センサー7 湿度                                                            3997
# センサー8 湿度                                                            3997
# センサー9 湿度                                                            3997
# ...

# %%
#相関係数を表示する
df_corr = df_hour_all.corr()

print(df_corr)
print(type(df_corr))
# Out:
#                S01H      S01M      S01L      S02H      S02M      S02L  \
# S01H       1.000000  0.953704  0.642276  0.947430  0.915559  0.807152
# S01M       0.953704  1.000000  0.821685  0.961446  0.978993  0.869218
# S01L       0.642276  0.821685  1.000000  0.695921  0.748584  0.693434
# S02H       0.947430  0.961446  0.695921  1.000000  0.946276  0.811757
# S02M       0.915559  0.978993  0.748584  0.946276  1.000000  0.844734
# ...             ...       ...       ...       ...       ...       ...
# センサー5 湿度  -0.435587 -0.297847 -0.153811 -0.397568 -0.291616 -0.156170
# センサー1 湿度  -0.458404 -0.230571 -0.031297 -0.338557 -0.303616 -0.163775
# センサー6 湿度  -0.424662 -0.546533 -0.445814 -0.341201 -0.552198 -0.536483
# センサー10 湿度 -0.143192 -0.272383 -0.356182 -0.156671 -0.253250 -0.299175
# センサー14 湿度 -0.617586 -0.625950 -0.535899 -0.610944 -0.661034 -0.645439
#
#                S03H      S03M      S03L      S04H  ...  センサー7 湿度  センサー8 湿度  \
# ...

# %%
#近似式の表示
import matplotlib.pyplot as plt
import numpy as np

x=df_hour_all[['S01H']]
y=df_hour_all[['S01M']]
plt.scatter(x,y)

plt.xlabel('S01Hのデータ')
plt.ylabel('S01Mのデータ')

print(x)
print(y)
# Out:
#                  S01H
# Day        Time
# 20210701.0 0:00  20.3
# 20210702.0 0:00  21.3
# 20210703.0 0:00  20.9
# 20210704.0 0:00  21.4
# 20210705.0 0:00  21.6
# 20210706.0 0:00  21.4
# 20210707.0 0:00  20.2
# 20210708.0 0:00  20.8
# 20210709.0 0:00  21.2
# 20210710.0 0:00  21.4
# 20210711.0 0:00  21.7
# 20210712.0 0:00  21.8
# 20210713.0 0:00  21.6
# 20210714.0 0:00  21.8
# 20210715.0 0:00  21.6
# 20210716.0 0:00  23.0
# 20210717.0 0:00  22.3
# 20210718.0 0:00  23.0
# 20210719.0 0:00  23.7
# 20210720.0 0:00  24.1
# 20210721.0 0:00  23.3
# 20210722.0 0:00  23.5
# 20210723.0 0:00  23.4
# 20210724.0 0:00  23.4
# 20210725.0 0:00  23.4
# 20210726.0 0:00  23.4
# 20210727.0 0:00   NaN
# 20210728.0 0:00  23.1
# 20210729.0 0:00  22.2
# 20210730.0 0:00   NaN
# 20210731.0 0:00  25.2
#                  S01M
# Day        Time
# 20210701.0 0:00   NaN
# 20210702.0 0:00  19.2
# 20210703.0 0:00   NaN
# 20210704.0 0:00  19.5
# 20210705.0 0:00  19.7
# 20210706.0 0:00  19.4
# 20210707.0 0:00  18.9
# ...

# %%
#小数点の桁数を変更する記述
print(df_base['S01L'].map('{:.0f}'.format))

print(df_base['S01H'].map('{:.4f}'.format))

# %%
#ggplot(data = df_base) + aes(x = ['Time'], y = ['S01H']) +   geom_point()

#ggplot(data = mpg) +              # mpgデータでキャンバス準備
#  aes(x = displ, y = cty) +       # displ,cty列をx,y軸にmapping
#  geom_point() +                  # 散布図を描く
#  facet_wrap(~ drv) +             # drv列に応じてパネル分割
#  theme_classic(base_size = 20)   # クラシックなテーマで

#ggplot(data = df_base,
#       mapping = aes(x=['Time'],
#                     y=['S01H'])) + geom_bar()

#geom_point：散布図
#geom_line：折れ線グラフ
#geom_smooth：平滑化されたグラフ
#geom_bar：棒グラフ
#geom_histogram：ヒストグラム
#geom_polygon：ポリゴングラフ
#geom_map：地図グラフ
#geom_dotplot：ドットグラフ

# %%
df_g = pd.DataFrame(df_base,columns=["S01H","S01M"])

df_g

df_g.plot()

#df_g.plot(x=["Time"], y=["S01H", "S01M"], kind="bar",figsize=(9,8))
#plt.show()


#df=pd.DataFrame(data,columns=["Name","Age","Height(cm)","Weight(kg)"])
#df.plot(x="Name", y=["Age", "Height(cm)", "Weight(kg)"], kind="bar",figsize=(9,8))
#plt.show()

# %%
#df_1 = df_base['T-S01H-H X4-Y7 H']
#df_1 = df_base['Time']
#df_1 = df_base['Time','T-S01H-H X4-Y7 H']

df_1 = df_base.loc[:,['S01H']]
df_1

# %%
df_1.plot()

#plt.bar(df_1)

# %%
import numpy as np
import matplotlib.pyplot as plt
 
left = np.array([1, 2, 3, 4, 5])
height = np.array([100, 200, 300, 400, 500])
plt.bar(left, height)

# %%
df_2 = df_base.loc[:,['S01M']]
df_2

# %%
df_2.plot()
#df_2.plot(kind="bar")

# %%
df_base.count()
