# %%
# REMCESセンサの温湿度の抽出、グラフ化
import pandas as pd
import numpy as np
import matplotlib

""" 生データから、Remcesセンサ(温湿度)のみ情報抽出し、CSVファイルにデータ出力 """
import glob

# 読み込みたいファイルのディレクトリを設定
path_list = glob.glob('C:/Users/2377/Desktop/作業スペース/神戸大温湿度データ2021.07/*')

# 空のDataFrameを定義
output_df = pd.DataFrame()

count = 0

# 1日から31日までの各ファイルの読み込みと、Remcesセンサ情報のみ取得しファイル出力
for file in path_list:
    """ CSVファイルデータをData Frameに変換 """
    df_temp = pd.read_csv(file, encoding='shift-jis', skiprows=1)

    # Remcesセンサ情報のみ抽出       
    df_remces = df_temp.iloc[:,146:207]

    count += 1

    # 日付毎のファイル情報を出力
    if count == 1:
        df_remces.to_csv("file_1.csv", encoding='shift-jis')
        df_day1 = df_remces
    elif count == 2:
        df_remces.to_csv("file_2.csv", encoding='shift-jis')
        df_day2 = df_remces
    elif count == 3:
        df_remces.to_csv("file_3.csv", encoding='shift-jis')
        df_day3 = df_remces
    elif count == 4:
        df_remces.to_csv("file_4.csv", encoding='shift-jis')
        df_day4 = df_remces
    elif count == 5:
        df_remces.to_csv("file_5.csv", encoding='shift-jis')
        df_day5 = df_remces
    elif count == 6:
        df_remces.to_csv("file_6.csv", encoding='shift-jis')
        df_day6 = df_remces
    elif count == 7:
        df_remces.to_csv("file_7.csv", encoding='shift-jis')
        df_day7 = df_remces
    elif count == 8:
        df_remces.to_csv("file_8.csv", encoding='shift-jis')
        df_day8 = df_remces
    elif count == 9:
        df_remces.to_csv("file_9.csv", encoding='shift-jis')
        df_day9 = df_remces
    elif count == 10:
        df_remces.to_csv("file_10.csv", encoding='shift-jis')
        df_day10 = df_remces
    elif count == 11:
        df_remces.to_csv("file_11.csv", encoding='shift-jis')
        df_day11 = df_remces
    elif count == 12:
        df_remces.to_csv("file_12.csv", encoding='shift-jis')
        df_day12 = df_remces
    elif count == 13:
        df_remces.to_csv("file_13.csv", encoding='shift-jis')
        df_day13 = df_remces
    elif count == 14:
        df_remces.to_csv("file_14.csv", encoding='shift-jis')
        df_day14 = df_remces
    elif count == 15:
        df_remces.to_csv("file_15.csv", encoding='shift-jis')
        df_day15 = df_remces
    elif count == 16:
        df_remces.to_csv("file_16.csv", encoding='shift-jis')
        df_day16 = df_remces
    elif count == 17:
        df_remces.to_csv("file_17.csv", encoding='shift-jis')
        df_day17 = df_remces
    elif count == 18:
        df_remces.to_csv("file_18.csv", encoding='shift-jis')
        df_day18 = df_remces
    elif count == 19:
        df_remces.to_csv("file_19.csv", encoding='shift-jis')
        df_day19 = df_remces
    elif count == 20:
        df_remces.to_csv("file_20.csv", encoding='shift-jis')
        df_day20 = df_remces
    elif count == 21:
        df_remces.to_csv("file_21.csv", encoding='shift-jis')
        df_day21 = df_remces
    elif count == 22:
        df_remces.to_csv("file_22.csv", encoding='shift-jis')
        df_day22 = df_remces
    elif count == 23:
        df_remces.to_csv("file_23.csv", encoding='shift-jis')
        df_day23 = df_remces
    elif count == 24:
        df_remces.to_csv("file_24.csv", encoding='shift-jis')
        df_day24 = df_remces
    elif count == 25:
        df_remces.to_csv("file_25.csv", encoding='shift-jis')
        df_day25 = df_remces
    elif count == 26:
        df_remces.to_csv("file_26.csv", encoding='shift-jis')
        df_day26 = df_remces
    elif count == 27:
        df_remces.to_csv("file_27.csv", encoding='shift-jis')
        df_day27 = df_remces
    elif count == 28:
        df_remces.to_csv("file_28.csv", encoding='shift-jis')
        df_day28 = df_remces
    elif count == 29:
        df_remces.to_csv("file_29.csv", encoding='shift-jis')
        df_day29 = df_remces
    elif count == 30:
        df_remces.to_csv("file_30.csv", encoding='shift-jis')
        df_day30 = df_remces
    elif count == 31:
        df_remces.to_csv("file_31.csv", encoding='shift-jis')
        df_day31 = df_remces
# Out:
# C:\Users\2377\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (1,16,20,51,52,88,91,100,101,104,105,106,118,124,125,126,127,128,129,130,131,132,141,142,143,144,145,146,147,267,268,269,270,271,272,554,561,562,563,566,567,574,575,576,579,580,587,588,589,592,593,600,601,602,605,606,613,614,615,618,619,626,627,628,631,632,639,640,641,644,645,652,653,654,657,658,665,666,667,670,671,678,679,680,683,684,691,692,693,696,697,704,705,706,709,710,717,718,719,722,723,730,731,732,735,736,743,744,745,748,749,756,757,758,761,762,767,768,769,772,773,775) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# ...

# %%
df_day1
# Out:
#      EF-S102 寿司厨房 排気ﾌｧﾝ　状態                                             \
# 0                                                     分
# 1                                                     1
# 2                                                     1
# 3                                                     1
# 4                                                     1
# ...                                                 ...
# 1436                                                  1
# 1437                                                  1
# 1438                                                  1
# 1439                                                  1
# 1440                                                  1
#
#      EF-S104 炊飯室 排気ﾌｧﾝ　状態                                              \
# 0                                                     分
# 1                                                     1
# 2                                                     1
# ...

# %%
df_day21
# Out:
#      T-S01H-H X4-Y7 H 温度                                               \
# 0                                                   NaN
# 1                                                  23.3
# 2                                                  23.3
# 3                                                  23.4
# 4                                                  23.4
# ...                                                 ...
# 1436                                               23.6
# 1437                                               23.5
# 1438                                               23.5
# 1439                                               23.5
# 1440                                               23.5
#
#      T-S01H-H X4-Y7 H 湿度                                               \
# 0                                                   NaN
# 1                                                  54.0
# 2                                                  54.0
# ...

# %%
# 1日から31日までデータに日付情報を入れて縦に結合する処理

# Dayというカラムを追加
df_day1.insert(loc = 0, column= 'Day', value= '20210701')
df_day2.insert(loc = 0, column= 'Day', value= '20210702')
df_day3.insert(loc = 0, column= 'Day', value= '20210703')
df_day4.insert(loc = 0, column= 'Day', value= '20210704')
df_day5.insert(loc = 0, column= 'Day', value= '20210705')
df_day6.insert(loc = 0, column= 'Day', value= '20210706')
df_day7.insert(loc = 0, column= 'Day', value= '20210707')
df_day8.insert(loc = 0, column= 'Day', value= '20210708')
df_day9.insert(loc = 0, column= 'Day', value= '20210709')
df_day10.insert(loc = 0, column= 'Day', value= '20210710')
df_day11.insert(loc = 0, column= 'Day', value= '20210711')
df_day12.insert(loc = 0, column= 'Day', value= '20210712')
df_day13.insert(loc = 0, column= 'Day', value= '20210713')
df_day14.insert(loc = 0, column= 'Day', value= '20210714')
df_day15.insert(loc = 0, column= 'Day', value= '20210715')
df_day16.insert(loc = 0, column= 'Day', value= '20210716')
df_day17.insert(loc = 0, column= 'Day', value= '20210717')
df_day18.insert(loc = 0, column= 'Day', value= '20210718')
df_day19.insert(loc = 0, column= 'Day', value= '20210719')
df_day20.insert(loc = 0, column= 'Day', value= '20210720')
df_day21.insert(loc = 0, column= 'Day', value= '20210721')
df_day22.insert(loc = 0, column= 'Day', value= '20210722')
df_day23.insert(loc = 0, column= 'Day', value= '20210723')
df_day24.insert(loc = 0, column= 'Day', value= '20210724')
df_day25.insert(loc = 0, column= 'Day', value= '20210725')
df_day26.insert(loc = 0, column= 'Day', value= '20210726')
df_day27.insert(loc = 0, column= 'Day', value= '20210727')
df_day28.insert(loc = 0, column= 'Day', value= '20210728')
df_day29.insert(loc = 0, column= 'Day', value= '20210729')
df_day30.insert(loc = 0, column= 'Day', value= '20210730')
df_day31.insert(loc = 0, column= 'Day', value= '20210731')

# %%
# 1行目は不要なので削除
df_day1 = df_day1[1:]
df_day2 = df_day2[1:]
df_day3 = df_day3[1:]
df_day4 = df_day4[1:]
df_day5 = df_day5[1:]
df_day6 = df_day6[1:]
df_day7 = df_day7[1:]
df_day8 = df_day8[1:]
df_day9 = df_day9[1:]
df_day10 = df_day10[1:]
df_day11 = df_day11[1:]
df_day12 = df_day12[1:]
df_day13 = df_day13[1:]
df_day14 = df_day14[1:]
df_day15 = df_day15[1:]
df_day16 = df_day16[1:]
df_day17 = df_day17[1:]
df_day18 = df_day18[1:]
df_day19 = df_day19[1:]
df_day20 = df_day20[1:]
df_day21 = df_day21[1:]
df_day22 = df_day22[1:]
df_day23 = df_day23[1:]
df_day24 = df_day24[1:]
df_day25 = df_day25[1:]
df_day26 = df_day26[1:]
df_day27 = df_day27[1:]
df_day28 = df_day28[1:]
df_day29 = df_day29[1:]
df_day30 = df_day30[1:]
df_day31 = df_day31[1:]


# カラム名のスペースを削除
df_day1 = df_day1.rename(columns=lambda s: s.replace(" ",""))
df_day2 = df_day2.rename(columns=lambda s: s.replace(" ",""))
df_day3 = df_day3.rename(columns=lambda s: s.replace(" ",""))
df_day4 = df_day4.rename(columns=lambda s: s.replace(" ",""))
df_day5 = df_day5.rename(columns=lambda s: s.replace(" ",""))
df_day6 = df_day6.rename(columns=lambda s: s.replace(" ",""))
df_day7 = df_day7.rename(columns=lambda s: s.replace(" ",""))
df_day8 = df_day8.rename(columns=lambda s: s.replace(" ",""))
df_day9 = df_day9.rename(columns=lambda s: s.replace(" ",""))
df_day10 = df_day10.rename(columns=lambda s: s.replace(" ",""))
df_day11 = df_day11.rename(columns=lambda s: s.replace(" ",""))
df_day12 = df_day12.rename(columns=lambda s: s.replace(" ",""))
df_day13 = df_day13.rename(columns=lambda s: s.replace(" ",""))
df_day14 = df_day14.rename(columns=lambda s: s.replace(" ",""))
df_day15 = df_day15.rename(columns=lambda s: s.replace(" ",""))
df_day16 = df_day16.rename(columns=lambda s: s.replace(" ",""))
df_day17 = df_day17.rename(columns=lambda s: s.replace(" ",""))
df_day18 = df_day18.rename(columns=lambda s: s.replace(" ",""))
df_day19 = df_day19.rename(columns=lambda s: s.replace(" ",""))
df_day20 = df_day20.rename(columns=lambda s: s.replace(" ",""))
df_day21 = df_day21.rename(columns=lambda s: s.replace(" ",""))
df_day22 = df_day22.rename(columns=lambda s: s.replace(" ",""))
df_day23 = df_day23.rename(columns=lambda s: s.replace(" ",""))
df_day24 = df_day24.rename(columns=lambda s: s.replace(" ",""))
df_day25 = df_day25.rename(columns=lambda s: s.replace(" ",""))
df_day26 = df_day26.rename(columns=lambda s: s.replace(" ",""))
df_day27 = df_day27.rename(columns=lambda s: s.replace(" ",""))
df_day28 = df_day28.rename(columns=lambda s: s.replace(" ",""))
df_day29 = df_day29.rename(columns=lambda s: s.replace(" ",""))
df_day30 = df_day30.rename(columns=lambda s: s.replace(" ",""))
df_day31 = df_day31.rename(columns=lambda s: s.replace(" ",""))


# Dayに1分単位で日時情報を入力
dates_day1 = pd.date_range('/7/1/2021', periods=1440,  freq='min')
dates_day2 = pd.date_range('/7/2/2021', periods=1440,  freq='min')
dates_day3 = pd.date_range('/7/3/2021', periods=1440,  freq='min')
dates_day4 = pd.date_range('/7/4/2021', periods=1440,  freq='min')
dates_day5 = pd.date_range('/7/5/2021', periods=1440,  freq='min')
dates_day6 = pd.date_range('/7/6/2021', periods=1440,  freq='min')
dates_day7 = pd.date_range('/7/7/2021', periods=1440,  freq='min')
dates_day8 = pd.date_range('/7/8/2021', periods=1440,  freq='min')
dates_day9 = pd.date_range('/7/9/2021', periods=1440,  freq='min')
dates_day10 = pd.date_range('/7/10/2021', periods=1440,  freq='min')
dates_day11 = pd.date_range('/7/11/2021', periods=1440,  freq='min')
dates_day12 = pd.date_range('/7/12/2021', periods=1440,  freq='min')
dates_day13 = pd.date_range('/7/13/2021', periods=1440,  freq='min')
dates_day14 = pd.date_range('/7/14/2021', periods=1440,  freq='min')
dates_day15 = pd.date_range('/7/15/2021', periods=1440,  freq='min')
dates_day16 = pd.date_range('/7/16/2021', periods=1440,  freq='min')
dates_day17 = pd.date_range('/7/17/2021', periods=1440,  freq='min')
dates_day18 = pd.date_range('/7/18/2021', periods=1440,  freq='min')
dates_day19 = pd.date_range('/7/19/2021', periods=1440,  freq='min')
dates_day20 = pd.date_range('/7/20/2021', periods=1440,  freq='min')
dates_day21 = pd.date_range('/7/21/2021', periods=1440,  freq='min')
dates_day22 = pd.date_range('/7/22/2021', periods=1440,  freq='min')
dates_day23 = pd.date_range('/7/23/2021', periods=1440,  freq='min')
dates_day24 = pd.date_range('/7/24/2021', periods=1440,  freq='min')
dates_day25 = pd.date_range('/7/25/2021', periods=1440,  freq='min')
dates_day26 = pd.date_range('/7/26/2021', periods=1440,  freq='min')
dates_day27 = pd.date_range('/7/27/2021', periods=1440,  freq='min')
dates_day28 = pd.date_range('/7/28/2021', periods=1440,  freq='min')
dates_day29 = pd.date_range('/7/29/2021', periods=1440,  freq='min')
dates_day30 = pd.date_range('/7/30/2021', periods=1440,  freq='min')
dates_day31 = pd.date_range('/7/31/2021', periods=1440,  freq='min')


df_day1['Day'] = dates_day1
df_day2['Day'] = dates_day2
df_day3['Day'] = dates_day3
df_day4['Day'] = dates_day4
df_day5['Day'] = dates_day5
df_day6['Day'] = dates_day6
df_day7['Day'] = dates_day7
df_day8['Day'] = dates_day8
df_day9['Day'] = dates_day9
df_day10['Day'] = dates_day10
df_day11['Day'] = dates_day11
df_day12['Day'] = dates_day12
df_day13['Day'] = dates_day13
df_day14['Day'] = dates_day14
df_day15['Day'] = dates_day15
df_day16['Day'] = dates_day16
df_day17['Day'] = dates_day17
df_day18['Day'] = dates_day18
df_day19['Day'] = dates_day19
df_day20['Day'] = dates_day20
df_day21['Day'] = dates_day21
df_day22['Day'] = dates_day22
df_day23['Day'] = dates_day23
df_day24['Day'] = dates_day24
df_day25['Day'] = dates_day25
df_day26['Day'] = dates_day26
df_day27['Day'] = dates_day27
df_day28['Day'] = dates_day28
df_day29['Day'] = dates_day29
df_day30['Day'] = dates_day30
df_day31['Day'] = dates_day31

# %%
df_day1
# Out:
#                      Day EF-S102寿司厨房排気ﾌｧﾝ　状態 EF-S104炊飯室排気ﾌｧﾝ　状態  IH炊飯ジャー　電流  \
# 1    2021-07-01 00:00:00                   1                  1         3.5
# 2    2021-07-01 00:01:00                   1                  1         4.0
# 3    2021-07-01 00:02:00                   1                  1         3.7
# 4    2021-07-01 00:03:00                   1                  1         3.1
# 5    2021-07-01 00:04:00                   1                  1         3.2
# ...                  ...                 ...                ...         ...
# 1436 2021-07-01 23:55:00                   1                  1         3.5
# 1437 2021-07-01 23:56:00                   1                  1         3.3
# 1438 2021-07-01 23:57:00                   1                  1         3.7
# 1439 2021-07-01 23:58:00                   1                  1         3.2
# 1440 2021-07-01 23:59:00                   1                  1         3.3
#
# ...

# %%
df_day2
# Out:
#                      Day EF-S102寿司厨房排気ﾌｧﾝ　状態 EF-S104炊飯室排気ﾌｧﾝ　状態  IH炊飯ジャー　電流  \
# 1    2021-07-02 00:00:00                   1                  1         3.2
# 2    2021-07-02 00:01:00                   1                  1         3.7
# 3    2021-07-02 00:02:00                   1                  1         3.2
# 4    2021-07-02 00:03:00                   1                  1         3.3
# 5    2021-07-02 00:04:00                   1                  1         3.4
# ...                  ...                 ...                ...         ...
# 1436 2021-07-02 23:55:00                   1                  1         3.6
# 1437 2021-07-02 23:56:00                   1                  1         3.8
# 1438 2021-07-02 23:57:00                   1                  1         3.7
# 1439 2021-07-02 23:58:00                   1                  1         3.6
# 1440 2021-07-02 23:59:00                   1                  1         3.5
#
# ...

# %%
df_month = pd.concat([df_day1, df_day2, df_day3, df_day4, df_day5, df_day6, df_day7, df_day8, df_day9, df_day10, 
                      df_day11, df_day12, df_day13, df_day14, df_day15, df_day16, df_day17, df_day18, df_day19, df_day20,
                      df_day21, df_day22, df_day23, df_day24, df_day25, df_day26, df_day27, df_day28, df_day29, df_day30, df_day31])
df_month
# Out:
#                      Day EF-S102寿司厨房排気ﾌｧﾝ　状態 EF-S104炊飯室排気ﾌｧﾝ　状態 IH炊飯ジャー　電流  \
# 1    2021-07-01 00:00:00                   1                  1        3.5
# 2    2021-07-01 00:01:00                   1                  1        4.0
# 3    2021-07-01 00:02:00                   1                  1        3.7
# 4    2021-07-01 00:03:00                   1                  1        3.1
# 5    2021-07-01 00:04:00                   1                  1        3.2
# ...                  ...                 ...                ...        ...
# 1436 2021-07-31 23:55:00                   1                  1        4.8
# 1437 2021-07-31 23:56:00                   1                  1        3.6
# 1438 2021-07-31 23:57:00                   1                  1        3.0
# 1439 2021-07-31 23:58:00                   1                  1        3.2
# 1440 2021-07-31 23:59:00                   1                  1        2.9
#
# ...

# %%
df_month= df_month.drop(['EF-S102寿司厨房排気ﾌｧﾝ　状態',
                         'EF-S104炊飯室排気ﾌｧﾝ　状態',
                         'IH炊飯ジャー　電流',
                         'T-S15L-HX6-Y31L温度',
                         'T-S15L-HX6-Y31L温度',
                         'T-S15L-HX6-Y31L湿度',
                         'T-S16L-HX6-Y32L温度',
                         'T-S16L-HX6-Y32L湿度',
                         'T-S17L-HX6-Y33L温度'], axis=1)

# %%
df_month
# Out:
#                      Day T-S01H-HX4-Y7H温度 T-S01H-HX4-Y7H湿度 T-S01M-TX4-Y7M温度  \
# 1    2021-07-01 00:00:00             20.3             74.0             99.9
# 2    2021-07-01 00:01:00             20.3             74.0             99.9
# 3    2021-07-01 00:02:00             20.3             74.0             99.9
# 4    2021-07-01 00:03:00             20.3             74.0             99.9
# 5    2021-07-01 00:04:00             20.3             74.0             99.9
# ...                  ...              ...              ...              ...
# 1436 2021-07-31 23:55:00             25.2             99.9             22.1
# 1437 2021-07-31 23:56:00             25.2             99.9             22.1
# 1438 2021-07-31 23:57:00             25.2             99.9             22.1
# 1439 2021-07-31 23:58:00             25.2             99.9             22.1
# 1440 2021-07-31 23:59:00             25.2             99.9             22.1
#
# ...

# %%
print(df_month.where(df_month == 99.9))
# Out:
#      Day T-S01H-HX4-Y7H温度 T-S01H-HX4-Y7H湿度 T-S01M-TX4-Y7M温度 T-S01L-TX4-Y7L温度  \
# 1    NaT              NaN              NaN             99.9              NaN
# 2    NaT              NaN              NaN             99.9              NaN
# 3    NaT              NaN              NaN             99.9              NaN
# 4    NaT              NaN              NaN             99.9              NaN
# 5    NaT              NaN              NaN             99.9              NaN
# ...   ..              ...              ...              ...              ...
# 1436 NaT              NaN             99.9              NaN              NaN
# 1437 NaT              NaN             99.9              NaN              NaN
# 1438 NaT              NaN             99.9              NaN              NaN
# 1439 NaT              NaN             99.9              NaN              NaN
# 1440 NaT              NaN             99.9              NaN              NaN
#
# ...

# %%
df_month = df_month.replace(99.9,0) # 「99.9」を「0」に変更する
df_month = df_month.replace(99,0) # 「99.9」を「0」に変更する
df_month
# Out:
#                      Day T-S01H-HX4-Y7H温度 T-S01H-HX4-Y7H湿度 T-S01M-TX4-Y7M温度  \
# 1    2021-07-01 00:00:00             20.3             74.0                0
# 2    2021-07-01 00:01:00             20.3             74.0                0
# 3    2021-07-01 00:02:00             20.3             74.0                0
# 4    2021-07-01 00:03:00             20.3             74.0                0
# 5    2021-07-01 00:04:00             20.3             74.0                0
# ...                  ...              ...              ...              ...
# 1436 2021-07-31 23:55:00             25.2                0             22.1
# 1437 2021-07-31 23:56:00             25.2                0             22.1
# 1438 2021-07-31 23:57:00             25.2                0             22.1
# 1439 2021-07-31 23:58:00             25.2                0             22.1
# 1440 2021-07-31 23:59:00             25.2                0             22.1
#
# ...

# %%
df_month = df_month.replace('******',0) # 「99.9」を「0」に変更する
df_month
# Out:
#                      Day T-S01H-HX4-Y7H温度 T-S01H-HX4-Y7H湿度 T-S01M-TX4-Y7M温度  \
# 1    2021-07-01 00:00:00             20.3             74.0                0
# 2    2021-07-01 00:01:00             20.3             74.0                0
# 3    2021-07-01 00:02:00             20.3             74.0                0
# 4    2021-07-01 00:03:00             20.3             74.0                0
# 5    2021-07-01 00:04:00             20.3             74.0                0
# ...                  ...              ...              ...              ...
# 1436 2021-07-31 23:55:00             25.2                0             22.1
# 1437 2021-07-31 23:56:00             25.2                0             22.1
# 1438 2021-07-31 23:57:00             25.2                0             22.1
# 1439 2021-07-31 23:58:00             25.2                0             22.1
# 1440 2021-07-31 23:59:00             25.2                0             22.1
#
# ...

# %%
df_month = df_month.fillna(0)
df_month
# Out:
#                      Day T-S01H-HX4-Y7H温度 T-S01H-HX4-Y7H湿度 T-S01M-TX4-Y7M温度  \
# 1    2021-07-01 00:00:00             20.3             74.0                0
# 2    2021-07-01 00:01:00             20.3             74.0                0
# 3    2021-07-01 00:02:00             20.3             74.0                0
# 4    2021-07-01 00:03:00             20.3             74.0                0
# 5    2021-07-01 00:04:00             20.3             74.0                0
# ...                  ...              ...              ...              ...
# 1436 2021-07-31 23:55:00             25.2                0             22.1
# 1437 2021-07-31 23:56:00             25.2                0             22.1
# 1438 2021-07-31 23:57:00             25.2                0             22.1
# 1439 2021-07-31 23:58:00             25.2                0             22.1
# 1440 2021-07-31 23:59:00             25.2                0             22.1
#
# ...

# %%
#print(df_month.where(df_month == 99.9))
#print(df_month.where(df_month == 'NaN'))
#print(df_month.where(df_month == '******'))
#df_month.where(df_month == 99.9).head(100)

# %%
df_month.to_csv("file_month.csv", encoding='shift-jis')

# %%
#df_day12 = pd.concat([df_day1, df_day2])
#df_day12.head(20)

# %%
#df_day12.tail(20)

# %%
#df_day12.to_csv("file_day12.csv", encoding='shift-jis')

# %%
###「Pandasのプロット機能」###

# グラフ化に必要なものの準備
import matplotlib
import matplotlib.pyplot as plt

# 画像出力に必要なものの準備
#from ggplot import *

# データの扱いに必要なライブラリ
import pandas as pd
import numpy as np
import datetime as dt

# グラフを綺麗に描画するためのおまじない
plt.style.use('ggplot') 
font = {'family' : 'meiryo'}
matplotlib.rc('font', **font)

# グラフのサイズ、色の濃さ、タイトル表示
df_day1.plot.bar(y=['T-S01H-HX4-Y7H温度','T-S01L-TX4-Y7L温度'], alpha=0.8, figsize=(20,6))
plt.title(u'センサ『S01』の設置位置(高さ)毎の棒グラフ', size=16)
# Out:
# Text(0.5, 1.0, 'センサ『S01』の設置位置(高さ)毎の棒グラフ')

# %%
#df_corr = df_month.corr()

#print(df_corr)
#print(type(df_corr))

# %%
df_month
# Out:
#                      Day T-S01H-HX4-Y7H温度 T-S01H-HX4-Y7H湿度 T-S01M-TX4-Y7M温度  \
# 1    2021-07-01 00:00:00             20.3             74.0                0
# 2    2021-07-01 00:01:00             20.3             74.0                0
# 3    2021-07-01 00:02:00             20.3             74.0                0
# 4    2021-07-01 00:03:00             20.3             74.0                0
# 5    2021-07-01 00:04:00             20.3             74.0                0
# ...                  ...              ...              ...              ...
# 1436 2021-07-31 23:55:00             25.2                0             22.1
# 1437 2021-07-31 23:56:00             25.2                0             22.1
# 1438 2021-07-31 23:57:00             25.2                0             22.1
# 1439 2021-07-31 23:58:00             25.2                0             22.1
# 1440 2021-07-31 23:59:00             25.2                0             22.1
#
# ...

# %%
#1時間毎に抽出したデータをデータフレームに格納
df_hour = df_month.query('Day == "0:00"')

df_hour
# Out:
# Empty DataFrame
# ...

# %%
df_month['Day']
# Out:
# 1      2021-07-01 00:00:00
# 2      2021-07-01 00:01:00
# 3      2021-07-01 00:02:00
# 4      2021-07-01 00:03:00
# 5      2021-07-01 00:04:00
#                ...
# 1436   2021-07-31 23:55:00
# 1437   2021-07-31 23:56:00
# 1438   2021-07-31 23:57:00
# 1439   2021-07-31 23:58:00
# 1440   2021-07-31 23:59:00
# Name: Day, Length: 44640, dtype: datetime64[ns]

# %%
df_month['Day'] = pd.to_datetime(df_month['Day'], format='%Y/%m月%d日-%H:%M')
print(df_month)
# Out:
#                      Day T-S01H-HX4-Y7H温度 T-S01H-HX4-Y7H湿度 T-S01M-TX4-Y7M温度  \
# 1    2021-07-01 00:00:00             20.3             74.0                0
# 2    2021-07-01 00:01:00             20.3             74.0                0
# 3    2021-07-01 00:02:00             20.3             74.0                0
# 4    2021-07-01 00:03:00             20.3             74.0                0
# 5    2021-07-01 00:04:00             20.3             74.0                0
# ...                  ...              ...              ...              ...
# 1436 2021-07-31 23:55:00             25.2                0             22.1
# 1437 2021-07-31 23:56:00             25.2                0             22.1
# 1438 2021-07-31 23:57:00             25.2                0             22.1
# 1439 2021-07-31 23:58:00             25.2                0             22.1
# 1440 2021-07-31 23:59:00             25.2                0             22.1
#
# ...

# %%
#時間の範囲指定によるデータ抽出　「.to_datetime」
df_month.index = pd.to_datetime(df_month['Day'], format='%Y/%m月%d日-%H:%M').values
#df_month = df_month.drop(columns='Day')

#範囲を指定
df_month['2021-07-01 00:00:00' : '2021-07-01 01:00:00']

#参考ページ
#https://qiita.com/mSpring/items/6ec1ab28dcb261db2c73
# Out:
#                                     Day T-S01H-HX4-Y7H温度 T-S01H-HX4-Y7H湿度  \
# 2021-07-01 00:00:00 2021-07-01 00:00:00             20.3             74.0
# 2021-07-01 00:01:00 2021-07-01 00:01:00             20.3             74.0
# 2021-07-01 00:02:00 2021-07-01 00:02:00             20.3             74.0
# 2021-07-01 00:03:00 2021-07-01 00:03:00             20.3             74.0
# 2021-07-01 00:04:00 2021-07-01 00:04:00             20.3             74.0
# ...                                 ...              ...              ...
# 2021-07-01 00:56:00 2021-07-01 00:56:00             21.6             59.0
# 2021-07-01 00:57:00 2021-07-01 00:57:00             21.6             59.0
# 2021-07-01 00:58:00 2021-07-01 00:58:00             21.6             60.0
# 2021-07-01 00:59:00 2021-07-01 00:59:00             21.6             60.0
# 2021-07-01 01:00:00 2021-07-01 01:00:00             21.6             59.0
#
#                     T-S01M-TX4-Y7M温度 T-S01L-TX4-Y7L温度 T-S02H-CX6-Y6H温度  \
# ...

# %%
df_month['2021-07-01 00:00:00' : '2021-07-10 01:00:00']
# Out:
#                                     Day T-S01H-HX4-Y7H温度 T-S01H-HX4-Y7H湿度  \
# 2021-07-01 00:00:00 2021-07-01 00:00:00             20.3             74.0
# 2021-07-01 00:01:00 2021-07-01 00:01:00             20.3             74.0
# 2021-07-01 00:02:00 2021-07-01 00:02:00             20.3             74.0
# 2021-07-01 00:03:00 2021-07-01 00:03:00             20.3             74.0
# 2021-07-01 00:04:00 2021-07-01 00:04:00             20.3             74.0
# ...                                 ...              ...              ...
# 2021-07-10 00:56:00 2021-07-10 00:56:00             21.5             69.0
# 2021-07-10 00:57:00 2021-07-10 00:57:00             21.4             68.0
# 2021-07-10 00:58:00 2021-07-10 00:58:00             21.4             68.0
# 2021-07-10 00:59:00 2021-07-10 00:59:00             21.4             69.0
# 2021-07-10 01:00:00 2021-07-10 01:00:00             21.5             69.0
#
#                     T-S01M-TX4-Y7M温度 T-S01L-TX4-Y7L温度 T-S02H-CX6-Y6H温度  \
# ...

# %%
#各日の0時0分のみ抽出　「.at_time」
print(df_month.at_time('00:00:00'))
# Out:
#                   Day T-S01H-HX4-Y7H温度 T-S01H-HX4-Y7H湿度 T-S01M-TX4-Y7M温度  \
# 2021-07-01 2021-07-01             20.3             74.0                0
# 2021-07-02 2021-07-02             21.3             54.0             19.2
# 2021-07-03 2021-07-03             20.9             64.0                0
# 2021-07-04 2021-07-04             21.4             61.0             19.5
# 2021-07-05 2021-07-05             21.6             60.0             19.7
# 2021-07-06 2021-07-06             21.4             60.0             19.4
# 2021-07-07 2021-07-07             20.2             67.0             18.9
# 2021-07-08 2021-07-08             20.8             63.0             18.8
# 2021-07-09 2021-07-09             21.2             66.0                0
# 2021-07-10 2021-07-10             21.4             67.0             19.1
# 2021-07-11 2021-07-11             21.7             66.0             19.3
# 2021-07-12 2021-07-12             21.8             56.0             19.4
# ...

# %%
df_month
# Out:
#                      Day T-S01H-HX4-Y7H温度 T-S01H-HX4-Y7H湿度 T-S01M-TX4-Y7M温度  \
# 1    2021-07-01 00:00:00             20.3             74.0             99.9
# 2    2021-07-01 00:01:00             20.3             74.0             99.9
# 3    2021-07-01 00:02:00             20.3             74.0             99.9
# 4    2021-07-01 00:03:00             20.3             74.0             99.9
# 5    2021-07-01 00:04:00             20.3             74.0             99.9
# ...                  ...              ...              ...              ...
# 1436 2021-07-31 23:55:00             25.2             99.9             22.1
# 1437 2021-07-31 23:56:00             25.2             99.9             22.1
# 1438 2021-07-31 23:57:00             25.2             99.9             22.1
# 1439 2021-07-31 23:58:00             25.2             99.9             22.1
# 1440 2021-07-31 23:59:00             25.2             99.9             22.1
#
# ...

# %%
df_S01H = df_month['T-S01H-HX4-Y7H温度']
df_S01H
# Out:
# 2021-07-01 00:00:00    20.3
# 2021-07-01 00:01:00    20.3
# 2021-07-01 00:02:00    20.3
# 2021-07-01 00:03:00    20.3
# 2021-07-01 00:04:00    20.3
#                        ...
# 2021-07-31 23:55:00    25.2
# 2021-07-31 23:56:00    25.2
# 2021-07-31 23:57:00    25.2
# 2021-07-31 23:58:00    25.2
# 2021-07-31 23:59:00    25.2
# Name: T-S01H-HX4-Y7H温度, Length: 44640, dtype: object

# %%
df_S01H.at_time(('00:00:00'))
# Out:
# 2021-07-01    20.3
# 2021-07-02    21.3
# 2021-07-03    20.9
# 2021-07-04    21.4
# 2021-07-05    21.6
# 2021-07-06    21.4
# 2021-07-07    20.2
# 2021-07-08    20.8
# 2021-07-09    21.2
# 2021-07-10    21.4
# 2021-07-11    21.7
# 2021-07-12    21.8
# 2021-07-13    21.6
# 2021-07-14    21.8
# 2021-07-15    21.6
# 2021-07-16    23.0
# 2021-07-17    22.3
# 2021-07-18    23.0
# 2021-07-19    23.7
# 2021-07-20    24.1
# 2021-07-21    23.3
# 2021-07-22    23.5
# 2021-07-23    23.4
# 2021-07-24    23.4
# 2021-07-25    23.4
# 2021-07-26    23.4
# 2021-07-27       0
# 2021-07-28    23.1
# 2021-07-29    22.2
# 2021-07-30       0
# 2021-07-31    25.2
# Name: T-S01H-HX4-Y7H温度, dtype: object

# %%
###「Pandasのプロット機能」###

# グラフ化に必要なものの準備
import matplotlib
import matplotlib.pyplot as plt

# 画像出力に必要なものの準備
#from ggplot import *

# データの扱いに必要なライブラリ
import pandas as pd
import numpy as np
import datetime as dt

# グラフを綺麗に描画するためのおまじない
plt.style.use('ggplot') 
font = {'family' : 'meiryo'}
matplotlib.rc('font', **font)

# グラフのサイズ、色の濃さ、タイトル表示
df_month.plot.bar(y=['Day'], alpha=0.8, figsize=(20,6))
#df_month.plot.bar(y=['Day','T-S01L-TX4-Y7L温度'], alpha=0.8, figsize=(20,6))
plt.title(u'センサ『S01』の棒グラフ', size=16)
# Out:
# Text(0.5, 1.0, 'センサ『S01』の棒グラフ')

# %%
df_month['T-S01H-HX4-Y7H温度']

# %%
df_day1.head(3)

# %%
df_month.head(3)

# %%
df_month.count()

# %%
s_bool = df_month['T-S01H-HX4-Y7H温度'] == 20.3
print(s_bool)

# %%
df_month.describe() #要約統計量の取得　(カウント数、平均値、標準偏差、最小値～最大値(四分位数)など)

# %%
df_day1.describe()

# %%
#psycopg2のサポート範囲 (Python 3.4～3.8)の確認

import sys

print(sys.version)

# %%
#pip install sqlalchemy

# %%
# psycopg2（2.9.1）がインストールされている事を確認
#　…PostgreSQLデータベースアダプタ、PythonからPostgreSQLへアクセスするためのライブラリ

# SQLAlchemy (1.4.7)がインストールされている事を確認
#  …PythonのためのORMライブラリ、ORMライブラリの一つ

pip list

# %%
import psycopg2
from sqlalchemy import create_engine
import pandas as pd
 
#接続情報、実際は、環境に合わせて設定すること
connection_config = {
    'user' : 'pgusr', 
    'password' : 'postgres',
    'host' : 'localhost', 
#    'host' : '172.0.0.1', 
    'port' : '5432',
    'database' : 'remces_development', 
}

engine = create_engine('postgresql://{user}:{password}@{host}:{port}/{database}'
                      .format(**connection_config))

#select * from sync_log;

#test_sql1 = (SELECT * FROM sync_log)
#test_result1 = pd.read_sql(test_sql1,connector)

# %%
#上記クエリの実行結果を確認
#test_result1.head()

# %%
#テスト用のテーブル作成
df = pd.DataFrame( {'氏名':['高橋', '伊藤', '渡辺'],
                    '出席番号':['a001', 'a002', 'a005'],
                    '国語':[5,6,7]}).set_index('氏名')

#作成したテーブルデータをPostgreSQLへ保存
df.to_sql('test_table01', con=engine, if_exists='replace')

# %%
#作成したテーブルデータ「1か月単位の集計情報」をPostgreSQLへ保存

df_month.to_sql('test_table02', con=engine, if_exists='replace')

#メモ：csv⇒dfへ読み込み⇒DBへ保管も可能
#参考動画：https://www.youtube.com/watch?v=fYqjHspuvd0

# %%
# sql=''のカッコ内で、SQL命令を実行する事ができる
# conの引数にはDBへの接続情報を渡す

df_read = pd.read_sql(sql='SELECT * FROM test_table02;', con=engine)

df_read
# Out:
#        index                 Day T-S01H-HX4-Y7H温度 T-S01H-HX4-Y7H湿度  \
# 0          1 2021-07-01 00:00:00             20.3             74.0
# 1          2 2021-07-01 00:01:00             20.3             74.0
# 2          3 2021-07-01 00:02:00             20.3             74.0
# 3          4 2021-07-01 00:03:00             20.3             74.0
# 4          5 2021-07-01 00:04:00             20.3             74.0
# ...      ...                 ...              ...              ...
# 44635   1436 2021-07-31 23:55:00             25.2             99.9
# 44636   1437 2021-07-31 23:56:00             25.2             99.9
# 44637   1438 2021-07-31 23:57:00             25.2             99.9
# 44638   1439 2021-07-31 23:58:00             25.2             99.9
# 44639   1440 2021-07-31 23:59:00             25.2             99.9
#
#       T-S01M-TX4-Y7M温度 T-S01L-TX4-Y7L温度 T-S02H-CX6-Y6H温度 T-S02H-CX6-Y6H湿度  \
# 0                 99.9             15.2             19.2             80.1
# ...
